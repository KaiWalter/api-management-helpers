# %% [markdown]
# # API Management operation statistics
#
# With this notebook API Management all defined operations are fetched and matched with their request counts fetched from Application Insights.
#
# ## Requirements
# - API Management integration to Application Insights
# - environment variables set to your values (see _environment variables_)
# - Service Principal in AAD with (see _creating a Service Principal for managing ARM resources_)
# - adal package installed into current jupyter kernel (see _Install the adap pip packagel in the current Jupyter kernel_)
#
# ### environment variables
# These environment variables need to be set with correct values
#
# | name | purpose | source |
# | --- | --- | --- |
# | AzMgmtAppId | AppId in AAD to allow access to ARM resources in your subscription | see 'creating a Service Principal for managing ARM resources' |
# | AzMgmtPassword | Password for AppId above | see 'creating a Service Principal for managing ARM resources' |
# | AzMgmtTenant | Tentant Id of AAD used to manage Azure subscription  | Azure Portal; AAD used to manage Azure subscription |
# | AzMgmtSubscription | Id of subscription containing Api Management and Application Insights | Azure Portal |
# | AzApiMgmtResourceGroup | Resource Group containing Api Management | Azure Portal |
# | AzApiMgmtServiceName | API Management Service Name | Azure Portal |
# | AzAppInsightsAppId | Application Insights AppId | Azure Portal |
# | AzAppInsightsApiKey | Application Insights ApiKey used for REST API access | Azure Portal |
#
# This can be achieved with a PowerShell setting the environment variables for the current session and for the user persistently:
# ```
# Write-Host "setting Azure Environment secrets"
# $env:AzMgmtAppId = "{your-value}"
# [Environment]::SetEnvironmentVariable("AzMgmtAppId",$env:AzMgmtAppId,"User")
#
# $env:AzMgmtPassword = "{your-value}"
# [Environment]::SetEnvironmentVariable("AzMgmtPassword",$env:AzMgmtPassword,"User")
#
# $env:AzMgmtTenant = "{your-value}"
# [Environment]::SetEnvironmentVariable("AzMgmtTenant",$env:AzMgmtTenant,"User")
#
# $env:AzMgmtSubscription = "{your-value}"
# [Environment]::SetEnvironmentVariable("AzMgmtSubscription",$env:AzMgmtSubscription,"User")
#
# $env:AzApiMgmtResourceGroup = "{your-value}"
# [Environment]::SetEnvironmentVariable("AzApiMgmtResourceGroup",$env:AzApiMgmtResourceGroup,"User")
#
# $env:AzApiMgmtServiceName = "{your-value}"
# [Environment]::SetEnvironmentVariable("AzApiMgmtServiceName",$env:AzApiMgmtServiceName,"User")
#
# $env:AzAppInsightsAppId = "{your-value}"
# [Environment]::SetEnvironmentVariable("AzAppInsightsAppId",$env:AzAppInsightsAppId,"User")
#
# $env:AzAppInsightsApiKey = "{your-value}"
# [Environment]::SetEnvironmentVariable("AzAppInsightsApiKey",$env:AzAppInsightsApiKey,"User")
# ```
#
# ### creating a Service Principal for managing ARM resources
# To create a Service Principal with PowerShell login to your AAD/Azure subscription with AzureRM, switch to the target subscription (containing API Management and Application Insights resources) and execute these steps:
#
# ```
# $sp = New-AzureRmADServicePrincipal -DisplayName myAzureManagement -Password "thepassword"
# New-AzureRmRoleAssignment -RoleDefinitionName Contributor -ServicePrincipalName $sp.ApplicationId
# ```
#
# Note ```ApplicationId``` and put it into the environment variables.
#
# ### Install the adap pip packagel in the current Jupyter kernel
# To install adal package into your kernel, copy these code lines into a newly inserted cell and execute.
#
# ```python
# import sys
# !{sys.executable} -m pip install adal
# ```

# %%
# obtain authorization token to be used in API Management REST API
import adal
import os
import json

def getToken():
    AppId = os.environ.get('AzMgmtAppId')
    AppPassword = os.environ.get('AzMgmtPassword')
    tenantID = os.environ.get('AzMgmtTenant')
    authURL = "https://login.windows.net/" + tenantID
    resource = "https://management.azure.com/"

    context = adal.AuthenticationContext(
        authURL, validate_authority=tenantID, api_version=None)

    token = context.acquire_token_with_client_credentials(
        resource,
        AppId,
        AppPassword)

    return token

def getAuthorizationHeader():
    token = getToken()

    header = token['tokenType'] + ' ' + token['accessToken']

    return header


# ----------------------------------------------------------------------

authHeader = getAuthorizationHeader()

print(authHeader)
# Out:
# Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IlRpb0d5d3dsaHZkRmJYWjgxM1dwUGF5OUFsVSIsImtpZCI6IlRpb0d5d3dsaHZkRmJYWjgxM1dwUGF5OUFsVSJ9.....UAPDhV9uvGJ2NhRF7dVr8WWFdBU9jR30jbEb82fZoHL7vxHu9m6t_NbujYuZWzhDrsKS83YfCfAp4vcBlAXpSGh9vYk6t8Wz9EgzQpl9tvHmONxrc82V2A4eceV6bwRUfUKb1oBGWLmAsXYNCWNW9H2UAfq-cdqiDnrO7n5bk_7L9ERJqHAW2fct__iMiuUzvOxgksKtX95adS-vOIndoe0Di0lJnzD3nBpC38EOqQiGUn5wheyH-UXntzzvgixwCN_9eGYk_3qznTTy40ktsh6LGRWK8lfRv_mMIbxVLNfSaAV9IWRUKP66UgFPxU3m1Fw2tS1JeJi9q5pq0DkLow

# %%
# use API Management REST API to obtain APIs
import requests

resource = "https://management.azure.com"
resourceGroupName = os.environ.get('AzApiMgmtResourceGroup')
serviceName = os.environ.get('AzApiMgmtServiceName')
subscriptionId = os.environ.get('AzMgmtSubscription')
apiVersionSuffix = "?api-version=2017-03-01"
        
url = '{}/subscriptions/{}/resourceGroups/{}/providers/Microsoft.ApiManagement/service/{}/apis{}'.format(resource,subscriptionId,resourceGroupName,serviceName,apiVersionSuffix)
headers = {"Content-Type": "application/json","Authorization":authHeader}

response = requests.get(url,headers=headers)

# %%
print(response.json()['value'][:2])
# Out:
# [{'id': '/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/imt-adh-core-inbound', 'type': 'Microsoft.ApiManagement/service/apis', 'name': 'imt-adh-core-inbound', 'properties': {'displayName': 'IMT Assembly Data Hub - Core - Inbound', 'apiRevision': '1', 'description': 'IMT Assembly Data Hub (ADH) Inbound', 'serviceUrl': 'https://esb-stage.zeiss.com/public/api/imt/adh/core/inbound', 'path': 'public/api/imt/adh/core/inbound', 'protocols': ['https'], 'authenticationSettings': None, 'subscriptionKeyParameterNames': None, 'isCurrent': True}}, {'id': '/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/imt-adh-proboard-outbound', 'type': 'Microsoft.ApiManagement/service/apis', 'name': 'imt-adh-proboard-outbound', 'properties': {'displayName': 'IMT Assembly Data Hub - Core - Outbound', 'apiRevision': '1', 'description': 'IMT Assembly Data Hub Core Outbound calls', 'serviceUrl': 'https://esb-stage.zeiss.com/public/api/imt/adh/core/outbound', 'path': 'public/api/imt/adh/core/outbound', 'protocols': ['https'], 'authenticationSettings': None, 'subscriptionKeyParameterNames': None, 'isCurrent': True}}]

# %%
# transform API result into dataframe
import pandas as pd
apis = pd.DataFrame.from_dict(response.json()['value'])
apis.head(n=2)
# Out:
#                                                   id  \
# 0  /subscriptions/a5d101c8-7211-4151-9fb1-ab05427...
# 1  /subscriptions/a5d101c8-7211-4151-9fb1-ab05427...
#
#                         name  \
# 0       imt-adh-core-inbound
# 1  imt-adh-proboard-outbound
#
#                                           properties  \
# 0  {'displayName': 'IMT Assembly Data Hub - Core ...
# 1  {'displayName': 'IMT Assembly Data Hub - Core ...
#
#                                    type
# 0  Microsoft.ApiManagement/service/apis
# 1  Microsoft.ApiManagement/service/apis

# %%
# pull path from properties into data frame
path = apis.properties.apply(lambda x : x["path"])
apis = apis.assign(path=path)
apis.head(n=2)
# Out:
#                                                   id  \
# 0  /subscriptions/a5d101c8-7211-4151-9fb1-ab05427...
# 1  /subscriptions/a5d101c8-7211-4151-9fb1-ab05427...
#
#                         name  \
# 0       imt-adh-core-inbound
# 1  imt-adh-proboard-outbound
#
#                                           properties  \
# 0  {'displayName': 'IMT Assembly Data Hub - Core ...
# 1  {'displayName': 'IMT Assembly Data Hub - Core ...
#
#                                    type                              path
# 0  Microsoft.ApiManagement/service/apis   public/api/imt/adh/core/inbound
# 1  Microsoft.ApiManagement/service/apis  public/api/imt/adh/core/outbound

# %%
# create a data frame with all operations in all APIs
import requests
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
import urllib

def requests_retry_session(
    retries=3,
    backoff_factor=0.3,
    status_forcelist=(500, 502, 504),
    session=None,
):
    session = session or requests.Session()
    retry = Retry(
        total=retries,
        read=retries,
        connect=retries,
        backoff_factor=backoff_factor,
        status_forcelist=status_forcelist,
    )
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    return session

# get operations for a single API
def getOperations(id):
    url = '{}{}/operations{}'.format(resource,urllib.parse.quote(id),apiVersionSuffix)
    print(url)
    headers = {"Content-Type": "application/json","Authorization":authHeader}
    response = requests_retry_session().get(url,headers=headers)
    print(response.status_code)
    return response.json()["value"]

# loop thru all APIs, fetch operations
for index, api in apis.iterrows():
    print(index,api.id)
    apiOperations = pd.DataFrame.from_dict(getOperations(api.id))
    apiOperations['apiPath'] = api.path
    apiOperations['operation'] = apiOperations.apply(lambda x:'%s %s' % (x.properties['method'],x.properties['urlTemplate']),axis=1)
    if index == 0:
        operations = apiOperations
    else:
        operations = operations.append(apiOperations,ignore_index=True)
    
operations.head()
# Out:
# 0 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/imt-adh-core-inbound
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/imt-adh-core-inbound/operations?api-version=2017-03-01
# 200
# 1 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/imt-adh-proboard-outbound
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/imt-adh-proboard-outbound/operations?api-version=2017-03-01
# 200
# 2 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/imt-usapprize-inbound
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/imt-usapprize-inbound/operations?api-version=2017-03-01
# 200
# 3 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/null-api
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/null-api/operations?api-version=2017-03-01
# 200
# 4 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5a008a96baef870e1ce7d214
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5a008a96baef870e1ce7d214/operations?api-version=2017-03-01
# 200
# 5 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5ab20f99baef87161cfdea0c
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5ab20f99baef87161cfdea0c/operations?api-version=2017-03-01
# 200
# 6 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5a9052488be84eb60ea9c81d
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5a9052488be84eb60ea9c81d/operations?api-version=2017-03-01
# 200
# 7 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/vis-frame-database
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/vis-frame-database/operations?api-version=2017-03-01
# 200
# 8 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5a0eb9c6baef871334666245
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5a0eb9c6baef871334666245/operations?api-version=2017-03-01
# 200
# 9 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/59a5115bbaef8713606cdb93
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/59a5115bbaef8713606cdb93/operations?api-version=2017-03-01
# 200
# 10 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/58e5dda91b9b1a10bcc11161
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/58e5dda91b9b1a10bcc11161/operations?api-version=2017-03-01
# 200
# 11 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/vis-others
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/vis-others/operations?api-version=2017-03-01
# 200
# 12 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/590c7541baef870da8f6fa92
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/590c7541baef870da8f6fa92/operations?api-version=2017-03-01
# 200
# 13 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5b434e3313cce204bf229acd
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5b434e3313cce204bf229acd/operations?api-version=2017-03-01
# 200
# 14 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-core-system-sap-outbound-communication-sms
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-core-system-sap-outbound-communication-sms/operations?api-version=2017-03-01
# 200
# 15 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-core-system-sap-outbound-crm-ibases
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-core-system-sap-outbound-crm-ibases/operations?api-version=2017-03-01
# 200
# 16 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-crm---business-partners-(preview)
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-crm---business-partners-%28preview%29/operations?api-version=2017-03-01
# 200
# 17 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-crm---customer-care-tickets-(preview)
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-crm---customer-care-tickets-%28preview%29/operations?api-version=2017-03-01
# 200
# 18 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-crm---ibases
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-crm---ibases/operations?api-version=2017-03-01
# 200
# 19 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-crm-ibases-linking
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-crm-ibases-linking/operations?api-version=2017-03-01
# 200
# 20 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-crm---pricing-tool
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-crm---pricing-tool/operations?api-version=2017-03-01
# 200
# 21 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5ad723bd8934640216b53564
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5ad723bd8934640216b53564/operations?api-version=2017-03-01
# 200
# 22 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5b0e40dd9650f0f0ddc8b2ff
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5b0e40dd9650f0f0ddc8b2ff/operations?api-version=2017-03-01
# 200
# 23 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-fico–invoices–inbound
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-fico%E2%80%93invoices%E2%80%93inbound/operations?api-version=2017-03-01
# 200
# 24 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-fico---master-data---inbound
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-fico---master-data---inbound/operations?api-version=2017-03-01
# 200
# 25 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5b0e40afbd83549691e98a9f
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5b0e40afbd83549691e98a9f/operations?api-version=2017-03-01
# 200
# 26 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/58708fb88a42f152d44912f7
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/58708fb88a42f152d44912f7/operations?api-version=2017-03-01
# 200
# 27 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5a280fb9d039b4727d2f384a
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5a280fb9d039b4727d2f384a/operations?api-version=2017-03-01
# 200
# 28 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-global-license-activation-service
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-global-license-activation-service/operations?api-version=2017-03-01
# 200
# 29 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/598d2adcbaef871a285eab73
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/598d2adcbaef871a285eab73/operations?api-version=2017-03-01
# 200
# 30 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5890ce0e0a476911a0567e63
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5890ce0e0a476911a0567e63/operations?api-version=2017-03-01
# 200
# 31 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/57f61a470a47690a009a5668
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/57f61a470a47690a009a5668/operations?api-version=2017-03-01
# 200
# 32 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/58aafd2f0a47691480226f60
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/58aafd2f0a47691480226f60/operations?api-version=2017-03-01
# 200
# 33 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-hr-masterdata-(peopledoc)-outbound
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-hr-masterdata-%28peopledoc%29-outbound/operations?api-version=2017-03-01
# 200
# 34 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-internal---accessory
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-internal---accessory/operations?api-version=2017-03-01
# 200
# 35 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-internal-core-inbound-sap-crm-ibases
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-internal-core-inbound-sap-crm-ibases/operations?api-version=2017-03-01
# 200
# 36 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5922927473df858af5be756d
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5922927473df858af5be756d/operations?api-version=2017-03-01
# 200
# 37 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/57f5e9850a47690a009a5662
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/57f5e9850a47690a009a5662/operations?api-version=2017-03-01
# 200
# 38 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-internal-crm-ibases
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-internal-crm-ibases/operations?api-version=2017-03-01
# 200
# 39 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5b3772be895de72a436cb2cd
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5b3772be895de72a436cb2cd/operations?api-version=2017-03-01
# 200
# 40 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/'zeiss-internal---database-access
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/%27zeiss-internal---database-access/operations?api-version=2017-03-01
# 200
# 41 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-internal-dcc-ibases
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-internal-dcc-ibases/operations?api-version=2017-03-01
# 200
# 42 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/39c75c1888754a1d96b3f1896ba2ffe4
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/39c75c1888754a1d96b3f1896ba2ffe4/operations?api-version=2017-03-01
# 200
# 43 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/sip-dcc-outbound
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/sip-dcc-outbound/operations?api-version=2017-03-01
# 200
# 44 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-internal-sms-gateway
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-internal-sms-gateway/operations?api-version=2017-03-01
# 200
# 45 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/ssc-italy-outbound
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/ssc-italy-outbound/operations?api-version=2017-03-01
# 200
# 46 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-logistics-–-tracking-(eurolog)-–-inbound
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-logistics-%E2%80%93-tracking-%28eurolog%29-%E2%80%93-inbound/operations?api-version=2017-03-01
# 200
# 47 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5ac73aae48412a669f43c450
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5ac73aae48412a669f43c450/operations?api-version=2017-03-01
# 200
# 48 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-nexus---applauncher
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-nexus---applauncher/operations?api-version=2017-03-01
# 200
# 49 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5b0bdf7bf1db43d9dc30f04d
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5b0bdf7bf1db43d9dc30f04d/operations?api-version=2017-03-01
# 200
# 50 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-sd---invoices---inbound
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-sd---invoices---inbound/operations?api-version=2017-03-01
# 200
# 51 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5ab8a82317b85ccbd7a3ec05
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5ab8a82317b85ccbd7a3ec05/operations?api-version=2017-03-01
# 200
# 52 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-sd---material-data---outbound
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/zeiss-sd---material-data---outbound/operations?api-version=2017-03-01
# 200
# 53 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5abc7dd6eb99e9c0200cb5b5
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5abc7dd6eb99e9c0200cb5b5/operations?api-version=2017-03-01
# 200
# 54 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5ab90366e6f2e9aee80f9dcd
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5ab90366e6f2e9aee80f9dcd/operations?api-version=2017-03-01
# 200
# 55 /subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5a1e64f7930de4e625e7dd89
# https://management.azure.com/subscriptions/a5d101c8-7211-4151-9fb1-ab054271927b/resourceGroups/ZEISS.ESB.PROD/providers/Microsoft.ApiManagement/service/zeissesbprod/apis/5a1e64f7930de4e625e7dd89/operations?api-version=2017-03-01
# 200
#                            apiPath  \
# 0  public/api/imt/adh/core/inbound
# 1  public/api/imt/adh/core/inbound
# 2  public/api/imt/adh/core/inbound
# 3  public/api/imt/adh/core/inbound
# 4  public/api/imt/adh/core/inbound
#
#                                                   id  \
# 0  /subscriptions/a5d101c8-7211-4151-9fb1-ab05427...
# 1  /subscriptions/a5d101c8-7211-4151-9fb1-ab05427...
# 2  /subscriptions/a5d101c8-7211-4151-9fb1-ab05427...
# 3  /subscriptions/a5d101c8-7211-4151-9fb1-ab05427...
# 4  /subscriptions/a5d101c8-7211-4151-9fb1-ab05427...
#
#                        name                     operation  \
# 0  5a9821194fb40e0d0003fabf      PUT /confirmation/update
# 1  5a9821194fb40e0d0003fac0          PUT /delivery/update
# 2  5a992aa9588c821e981f7bb9      POST /missingpart/create
# 3  5a9821194fb40e0d0003fac1     PUT /planned-order/update
# 4  5a9821194fb40e0d0003fabe  PUT /production-order/update
#
#                                           properties  \
# 0  {'displayName': 'Confirmations', 'method': 'PU...
# 1  {'displayName': 'Deliveries', 'method': 'PUT',...
# 2  {'displayName': 'Missing Parts', 'method': 'PO...
# 3  {'displayName': 'Planned Orders', 'method': 'P...
# 4  {'displayName': 'Production Orders', 'method':...
#
#                                               type
# 0  Microsoft.ApiManagement/service/apis/operations
# 1  Microsoft.ApiManagement/service/apis/operations
# 2  Microsoft.ApiManagement/service/apis/operations
# 3  Microsoft.ApiManagement/service/apis/operations
# 4  Microsoft.ApiManagement/service/apis/operations

# %%
import requests
import urllib
import pandas as pd

appInsightsAppId = os.environ.get('AzAppInsightsAppId')
appInsightsApiKey = os.environ.get('AzAppInsightsApiKey')
appInsightsQuery = 'requests | where timestamp >= ago(7d) and tostring(customDimensions.ApimanagementServiceName) != "" and name !startswith "OPTIONS" and success == true | project apiOperation=tostring(customDimensions["Operation Name"]),itemCount | summarize calls=count() by  apiOperation'
appInsightsUrl = "https://api.applicationinsights.io/v1/apps/{}".format(appInsightsAppId)

url = '{}/query?query={}'.format(appInsightsUrl,urllib.parse.quote(appInsightsQuery))
headers = {"Content-Type": "application/json","x-api-key":appInsightsApiKey}

response = requests.get(url,headers=headers)

stats = pd.DataFrame.from_dict(response.json()["tables"][0]["rows"])
stats.columns = ['name','counter']
stats.head()
# Out:
#                        name  counter
# 0  594b6171f4255025c1db4594   150034
# 1  5a79fa254fb40e170085e59e    13166
# 2  5ac8f1284fb40e01b8b062de   150182
# 3  5a9cea784fb40e0d0003ff3f    10161
# 4  58e5de271b9b1a10bcc11163   198286

# %%
operationResults = pd.merge(operations,stats,on='name',how='left')[['apiPath','operation','counter']]
operationResults['counter'].fillna(0,inplace=True)
operationResults.head()
# Out:
#                            apiPath                     operation  counter
# 0  public/api/imt/adh/core/inbound  PUT /confirmation/update      2549.0
# 1  public/api/imt/adh/core/inbound  PUT /delivery/update          8336.0
# 2  public/api/imt/adh/core/inbound  POST /missingpart/create      1.0
# 3  public/api/imt/adh/core/inbound  PUT /planned-order/update     4644.0
# 4  public/api/imt/adh/core/inbound  PUT /production-order/update  781.0

# %%
operationResults.sort_values(by='counter', ascending=False)
# Out:
#                                            apiPath  \
# 85   public/api/core/vis/input
# 140  public/api/licensing/entitlement
# 84   public/api/core/vis/input
# 231  private/api/core/outbound
# 230  private/api/core/outbound
# 213  public/api/internal/accessory
# 249  private/api/core/outbound
# 285  public/api/logistics/tracking/eurolog/inbound
# 247  private/api/core/outbound
# 158  public/api/core
# 250  private/api/core/outbound
# 244  private/api/core/outbound
# 243  private/api/core/outbound
# 253  private/api/core/outbound
# 214  public/api/internal/accessory
# 238  private/api/core/outbound
# 275  private/api/flexera/outbound
# 236  private/api/core/outbound
# 251  private/api/core/outbound
# 217  public/api/internal-core
# 10   public/api/imt/adh/core/outbound
# 234  private/api/core/outbound
# 83   public/api/core/vis/input
# 252  private/api/core/outbound
# 163  public/api/core
# 196  public/api/core
# 5    public/api/imt/adh/core/inbound
# 194  public/api/core
# 136  public/api/license/activation
# 270  public/api/internal/data/cosmosdb
# ..                                 ...
# 139  public/api/licensing/entitlement
# 137  public/api/license/activation
# 100  public/api/experience/vis/cdb
# 135  public/api/license/activation
# 101  public/api/experience/vis/cdb
# 102  public/api/experience/vis/cdb
# 103  public/api/experience/vis/cdb
# 104  public/api/communication/sms
# 105  private/api/core/sap/communication/sms
# 106  private/api/core/sap/crm/ibases
# 109  public/api/crm/customer-care-tickets
# 110  public/api/crm/customer-care-tickets
# 111  public/api/crm/customer-care-tickets
# 112  public/api/crm/customer-care-tickets
# 113  public/api/crm/customer-care-tickets
# 114  public/api/crm/customer-care-tickets
# 115  public/api/crm/customer-care-tickets
# 116  public/api/crm/customer-care-tickets
# 117  public/api/crm/ibases
# 118  public/api/crm/ibases
# 120  public/api/crm/ibases/linking
# 121  public/api/crm/pricing
# 122  public/api/crm/pricing
# 123  public/api/crm/pricing
# 124  public/api/crm/pricing
# 125  public/api/dms
# 126  public/api/fico/cost-allocation/phone
# 128  public/api/fico/masterdata
# 129  public/api/fico/masterdata/synchronization
# 300  public/api/sharepoint
#
#                                                                                                                           operation  \
# 85   POST /orderstatus
# 140  POST /EntitlementItems/findBySerialNumbers
# 84   POST /orderlog
# 231  PUT /BusinessPartnerGeneral-Changed
# 230  PUT /BusinessPartnerAddress-Changed
# 213  GET /mnf/imt/adh/check-production-order/{productionorderno}/plant/{plantno}/ordertype/{ordertype}
# 249  PUT /ProductionOrder-Changed
# 285  POST /delivery-tracking
# 247  PUT /PlannedOrder-Changed
# 158  GET /customer/{customerid}
# 250  PUT /ProductionOrderConfirmation-Changed
# 244  PUT /MaterialSales-Changed
# 243  PUT /MaterialPlant-Changed
# 253  PUT /SalesOrder-Changed
# 214  GET /sd/imt/adh/check-sales-order/{salesorderno}/salesOrg/{salesOrg}/shippingPlant/{shippingPlant}/documentType/{documentType}
# 238  PUT /Delivery-Changed
# 275  PUT /customers?number={number}&country={country}&name={name}
# 236  PUT /Customer-Changed
# 251  PUT /PurchaseOrder-Changed
# 217  POST /documentdb/query
# 10   PUT /proboard2/sap/{resource}
# 234  PUT /Customer-Care-Ticket-Changed
# 83   POST /orderattachmentstream
# 252  PUT /SalesContract-Changed
# 163  GET /deliveries?externalOrderId={externalOrderId}
# 196  GET /contract/{contractid}/sma
# 5    PUT /sales-order/update
# 194  GET /sales-orders/findByExternalOrderId/{orderid}
# 136  GET /device/{hostId}/license
# 270  POST /documents/{database}/{collection}/query
# ..                                             ...
# 139  POST /EntitlementItems/findByChangeDate
# 137  POST /device/{hostId}/repair
# 100  PUT /consumer/
# 135  POST /device/{hostId}/activate
# 101  PUT /customer
# 102  PUT /visit/
# 103  POST /sample
# 104  POST /send
# 105  POST /send
# 106  PUT /
# 109  PUT /{customercareticketnumber}/report?interface={interface}
# 110  GET /externalreferencenumber/{externalreferencenumber}?interface={interface}
# 111  GET /{customercareticketnumber}
# 112  GET /changed?interface={interface}
# 113  POST /ibase/{ibaseid}?interface={interface}
# 114  POST /instrumentcode/{instrumentcode}/serialnumber/{serialnumber}?interface={interface}
# 115  POST /materialnumber/{materialnumber}/serialnumber/{serialnumber}?interface={interface}
# 116  GET /
# 117  GET /{iBaseNo}?format={format}
# 118  GET /materialnumber/{materialnumber}/serialnumber/{serialnumber}?format={format}
# 120  POST /add
# 121  GET /authorizations
# 122  GET /customers/{customerId}
# 123  GET /customers/
# 124  POST /tasks
# 125  POST /metadata/
# 126  POST /
# 128  GET /phone-cost-allocation
# 129  POST /phone
# 300  POST /
#
#       counter
# 85   478980.0
# 140  259147.0
# 84   198286.0
# 231  167120.0
# 230  164252.0
# 213  150182.0
# 249  150034.0
# 285  130631.0
# 247  120478.0
# 158  75091.0
# 250  71271.0
# 244  67140.0
# 243  58549.0
# 253  52431.0
# 214  52333.0
# 238  47644.0
# 275  44701.0
# 236  44684.0
# 251  41035.0
# 217  38184.0
# 10   37453.0
# 234  32782.0
# 83   25866.0
# 252  25551.0
# 163  24125.0
# 196  17852.0
# 5    17105.0
# 194  14484.0
# 136  13166.0
# 270  12714.0
# ..       ...
# 139  0.0
# 137  0.0
# 100  0.0
# 135  0.0
# 101  0.0
# 102  0.0
# 103  0.0
# 104  0.0
# 105  0.0
# 106  0.0
# 109  0.0
# 110  0.0
# 111  0.0
# 112  0.0
# 113  0.0
# 114  0.0
# 115  0.0
# 116  0.0
# 117  0.0
# 118  0.0
# 120  0.0
# 121  0.0
# 122  0.0
# 123  0.0
# 124  0.0
# 125  0.0
# 126  0.0
# 128  0.0
# 129  0.0
# 300  0.0
#
# [301 rows x 3 columns]
